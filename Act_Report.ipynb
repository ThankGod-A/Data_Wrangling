# %% [markdown]
# ### Act Report
# This report sums up the insights generated, and visualizations from the data wrangling project.

# %% [markdown]
# **Dog_Stage Analysis**
#
# **1**. Analysis of dog_stage with the highest average retweet_count and favorite_count was carried out. **Doggo, Puppo** had the highest average number of retweets with a count of 15614 while **Pupper** had the least average number of  retweet_count with a count of 1852.

# %%
#Dog_stage with the highest average retweet_count 
Twitter_archive_master.groupby('stage')['retweet_count'].mean().sort_values(ascending = False).astype(int)
# Out:
# stage
# doggo,puppo      15614
# doggo             5939
# puppo             5205
# floofer           3897
# doggo,pupper      3467
# doggo,floofer     2746
# pupper            1852
# Name: retweet_count, dtype: int64

# %%
#Dog_stage with the highest total retweet_count 
Twitter_archive_master.groupby('stage')['favorite_count'].sum().sort_values(ascending = False)
# Out:
# stage
# pupper           1161242
# doggo            1042296
# puppo             417560
# doggo,pupper       96718
# floofer            76427
# doggo,puppo        40280
# doggo,floofer      14353
# Name: favorite_count, dtype: int64

# %% [markdown]
# **2.** The stage with the most favorite_count was **Pupper** with a count of 1161242 whilst **doggo, floofer** had the least number of favorite_count with a count of 14353.

# %%
#Name with the highest total retweet_count 
Twitter_archive_master.groupby('name')['retweet_count'].sum().sort_values(ascending = False)
# Out:
# name
# Bo            58606
# Stephan       50546
# Duddles       36623
# Buddy         31015
# Jamesy        29526
#               ...
# Kollin           45
# Julio            43
# Christoper       41
# Kallie           35
# Bloo             35
# Name: retweet_count, Length: 909, dtype: int64

# %% [markdown]
# **3. Bo**, with a count of 58606 was the dog with the highest retweet_count while **Bloo** with 35 had the least retweet_count.
#
# **Bo** also is the most liked dog with a count of 155149, and **Christopher** with a count of 35 is the least liked dog.

# %% [markdown]
# **Correlation Analysis**
#
# A correlation analysis carried out between retweet_count and favorite_count was positive. The higher the retweet the higher the likes.  The coefficient is 0.86.

# %% [markdown]
# #### The most common used source
# Tweets were mainly sent from iPhone. One thousand eight hundred and thirty-nine (1839) users used iPhone as their device of choice to tweet while **‘TweetDeck’** is the least commonly used device with a count of nine (9). Therefore, **‘Twitter for iPhone’** is the most common source used to tweet.

# %% [markdown]
# #### The most dog stage
# The most common dog stage is **Pupper** with a count of 194 while **doggo,floofer** is the least common stage with a count of eight (8).

# %% [markdown]
# **Note**: I relied on stack overflow, youtube, and google for some of the code and for debugging.
#
# #### Limitation
# 1. The tweet status of thirty-one (31) users was missing from the dataset
# 2. So many columns were redundant because they are either not necessary or they contain too much missing data.
